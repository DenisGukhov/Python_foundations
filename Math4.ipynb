# %%
import numpy as np
from sympy import diff, symbols, cos, sin

# %%
x = Symbol('x')
y = x**5 + 4*sin(2*x) + cos(3*x + 3)
yprime = y.diff(x)
yprime
# Out:
# 5*x**4 - 3*sin(3*x + 3) + 8*cos(2*x)

# %% [markdown]
# # Task 2

# %%
import matplotlib.pyplot as plt

# %%
x1 = Symbol('x1')
y1 = sin(2*x1 + 1)
yprime1 = y1.diff(x1)
yprime1
# Out:
# 2*cos(2*x1 + 1)

# %%
y = lambda x: 2*np.cos(2*x+1)
# создаём рисунок с координатную плоскость
fig = plt.subplots()
# создаём область, в которой будет
# - отображаться график
x = np.linspace(-5, 5, 100)
# значения x, которые будут отображены
# количество элементов в созданном массиве
# - качество прорисовки графика 
# рисуем график
plt.plot(x, y(x))
# показываем график
plt.show()

# %%
x2 = Symbol('x2')
y2 = 2*cos(2*x2 + 1)
yprime2 = y2.diff(x2)
yprime2
# Out:
# -4*sin(2*x2 + 1)

# %%
y = lambda x: -4*np.sin(2*x+1)
# создаём рисунок с координатную плоскость
fig = plt.subplots()
# создаём область, в которой будет
# - отображаться график
x = np.linspace(-5, 5, 100)
# значения x, которые будут отображены
# количество элементов в созданном массиве
# - качество прорисовки графика 
# рисуем график
plt.plot(x, y(x))
# показываем график
plt.show()
