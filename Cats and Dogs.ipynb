# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'Удаленный хост принудительно разорвал существующее подключение', None, 10054, None))': /simple/keras-preprocessing/
#   Downloading tensorflow-2.10.0-cp39-cp39-win_amd64.whl (455.9 MB)
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\ds\anaconda\lib\site-packages (from tensorflow) (4.1.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\ds\anaconda\lib\site-packages (from tensorflow) (1.12.1)
# Collecting tensorflow-estimator<2.11,>=2.10.0
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
# Collecting tensorboard<2.11,>=2.10
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\ds\anaconda\lib\site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: six>=1.12.0 in c:\ds\anaconda\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: numpy>=1.20 in c:\ds\anaconda\lib\site-packages (from tensorflow) (1.21.5)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.0.1-py3-none-any.whl (5.4 kB)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: h5py>=2.9.0 in c:\ds\anaconda\lib\site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: setuptools in c:\ds\anaconda\lib\site-packages (from tensorflow) (61.2.0)
# Collecting keras<2.11,>=2.10.0
#   Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-22.9.24-py2.py3-none-any.whl (26 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.27.0-cp39-cp39-win_amd64.whl (1.5 MB)
# Collecting absl-py>=1.0.0
#   Downloading absl_py-1.3.0-py3-none-any.whl (124 kB)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\ds\anaconda\lib\site-packages (from tensorflow) (3.19.1)
# Collecting libclang>=13.0.0
#   Downloading libclang-14.0.6-py2.py3-none-win_amd64.whl (14.2 MB)
# Requirement already satisfied: packaging in c:\ds\anaconda\lib\site-packages (from tensorflow) (21.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\ds\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\ds\anaconda\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.3.4)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\ds\anaconda\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.27.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\ds\anaconda\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.0.3)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\ds\anaconda\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.33.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\ds\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\ds\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\ds\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.2.2)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\ds\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\ds\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\ds\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\ds\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\ds\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.3)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\ds\anaconda\lib\site-packages (from packaging->tensorflow) (3.0.4)
# Installing collected packages: oauthlib, requests-oauthlib, tensorboard-plugin-wit, tensorboard-data-server, google-auth-oauthlib, absl-py, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard, opt-einsum, libclang, keras-preprocessing, keras, google-pasta, gast, flatbuffers, astunparse, tensorflow
# Successfully installed absl-py-1.3.0 astunparse-1.6.3 flatbuffers-22.9.24 gast-0.4.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 keras-2.10.0 keras-preprocessing-1.1.2 libclang-14.0.6 oauthlib-3.2.2 opt-einsum-3.3.0 requests-oauthlib-1.3.1 tensorboard-2.10.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.10.0 tensorflow-estimator-2.10.0 tensorflow-io-gcs-filesystem-0.27.0 termcolor-2.0.1

# %%
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import vgg16
from keras.applications.inception_v3 import InceptionV3, preprocess_input
print(tf.__version__)
print(tf.executing_eagerly())
# Out:
# 2.10.0
# True

# %%
import os
from random import shuffle
from glob import glob

IMG_SIZE = (224, 224)  # размер входного изображения сети

train_files = glob('C:/DS/Netology/CV/C and D/train/*.jpg')
test_files = glob('C:/DS/Netology/CV/C and D/test/*.jpg')

# загружаем входное изображение и предобрабатываем
def load_image(path, target_size=IMG_SIZE):
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, target_size)
    return vgg16.preprocess_input(img)  # предобработка для VGG16

# функция-генератор загрузки обучающих данных с диска
def fit_generator(files, batch_size=32):
    batch_size = min(batch_size, len(files))
    while True:
        shuffle(files)
        for k in range(len(files) // batch_size):
            i = k * batch_size
            j = i + batch_size
            if j > len(files):
                j = - j % len(files)
            x = np.array([load_image(path) for path in files[i:j]])
            y = np.array([1. if os.path.basename(path).startswith('dog') else 0.
                          for path in files[i:j]])
            yield (x, y)

# функция-генератор загрузки тестовых изображений с диска
def predict_generator(files):
    while True:
        for path in files:
            yield np.array([load_image(path)])

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(16, 8))
for i, path in enumerate(train_files[:10], 1):
    subplot = fig.add_subplot(2, 5, i)
    subplot.set_title('%s' % path.split('/')[-1])
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, IMG_SIZE)
    plt.imshow(img)

# %%
# base_model - объект класса keras.models.Model (Functional Model)
base_model = vgg16.VGG16(weights='imagenet',
                         include_top=False,
                         input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3))

# %%
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.layers import BatchNormalization

# %%
# фиксируем все веса предобученной сети
for layer in base_model.layers:
    layer.trainable = False

x = base_model.layers[-5].output
# x = tf.keras.layers.Flatten()(x) # Flatten превращает тензор (14, 14, 512) в вектор, т.к. полносвзяанная модель принимает на вход вектор 
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.BatchNormalization(axis=-1, momentum=0.99, epsilon = 0.001, center=True, scale=True, 
                                                     beta_regularizer=None, gamma_regularizer=None )(x)
x = tf.keras.layers.Dense(1,  # один выход (бинарная классификация)
                          activation='sigmoid',  # функция активации  
                          kernel_regularizer=tf.keras.regularizers.l1(1e-4))(x)

model = tf.keras.Model(inputs=base_model.input, outputs=x, name='dogs_vs_cats')

# %%
model.summary()
# Out:
# Model: "dogs_vs_cats"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  batch_normalization (BatchN  (None, 512)              2048
#  ormalization)
#
#  dense (Dense)               (None, 1)                 513
#
# =================================================================
# Total params: 7,637,825
# Trainable params: 1,537
# Non-trainable params: 7,636,288
# _________________________________________________________________

# %%
model.compile(optimizer='adam', 
              loss='binary_crossentropy',  # функция потерь binary_crossentropy (log loss
              metrics=['accuracy'])

# %%
val_samples = 150  # число изображений в валидационной выборке

shuffle(train_files)  # перемешиваем обучающую выборку
validation_data = next(fit_generator(train_files[:val_samples], val_samples))
train_data = fit_generator(train_files[val_samples:])  # данные читаем функцией-генератором

# запускаем процесс обучения
model.fit(train_data,
          steps_per_epoch=10,  # число вызовов генератора за эпоху
          epochs=50,  # число эпох обучения
          validation_data=validation_data)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 33s 3s/step - loss: 0.6590 - accuracy: 0.6750 - val_loss: 1.1013 - val_accuracy: 0.6800
# Epoch 2/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.5506 - accuracy: 0.7250 - val_loss: 1.2482 - val_accuracy: 0.6333
# Epoch 3/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.4152 - accuracy: 0.8281 - val_loss: 0.5645 - val_accuracy: 0.8067
# Epoch 4/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.4023 - accuracy: 0.8188 - val_loss: 0.3530 - val_accuracy: 0.8800
# Epoch 5/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.3843 - accuracy: 0.8500 - val_loss: 0.2948 - val_accuracy: 0.8933
# Epoch 6/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.3390 - accuracy: 0.8625 - val_loss: 0.2992 - val_accuracy: 0.9200
# Epoch 7/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.3146 - accuracy: 0.8750 - val_loss: 0.2809 - val_accuracy: 0.9133
# Epoch 8/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.3069 - accuracy: 0.8813 - val_loss: 0.2914 - val_accuracy: 0.9200
# Epoch 9/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.2662 - accuracy: 0.9031 - val_loss: 0.3016 - val_accuracy: 0.9067
# Epoch 10/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.2852 - accuracy: 0.8719 - val_loss: 0.2586 - val_accuracy: 0.9133
# Epoch 11/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.2805 - accuracy: 0.8906 - val_loss: 0.2423 - val_accuracy: 0.9133
# Epoch 12/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.2801 - accuracy: 0.8875 - val_loss: 0.2202 - val_accuracy: 0.9133
# Epoch 13/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.2507 - accuracy: 0.9031 - val_loss: 0.2103 - val_accuracy: 0.9200
# Epoch 14/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.2652 - accuracy: 0.8687 - val_loss: 0.2123 - val_accuracy: 0.9133
# Epoch 15/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.2682 - accuracy: 0.8906 - val_loss: 0.2191 - val_accuracy: 0.9133
# Epoch 16/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.2699 - accuracy: 0.8844 - val_loss: 0.1995 - val_accuracy: 0.9133
# Epoch 17/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.2999 - accuracy: 0.9000 - val_loss: 0.1932 - val_accuracy: 0.9200
# Epoch 18/50
# 10/10 [==============================] - 32s 3s/step - loss: 0.2452 - accuracy: 0.9031 - val_loss: 0.1887 - val_accuracy: 0.9133
# Epoch 19/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.2604 - accuracy: 0.8938 - val_loss: 0.1919 - val_accuracy: 0.9133
# Epoch 20/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.2153 - accuracy: 0.9156 - val_loss: 0.1861 - val_accuracy: 0.9133
# Epoch 21/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.2111 - accuracy: 0.9219 - val_loss: 0.1837 - val_accuracy: 0.9133
# Epoch 22/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.1962 - accuracy: 0.9156 - val_loss: 0.1876 - val_accuracy: 0.9133
# Epoch 23/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.2347 - accuracy: 0.9156 - val_loss: 0.1909 - val_accuracy: 0.9133
# Epoch 24/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.2012 - accuracy: 0.9438 - val_loss: 0.1960 - val_accuracy: 0.9133
# Epoch 25/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.2280 - accuracy: 0.9125 - val_loss: 0.1927 - val_accuracy: 0.9133
# Epoch 26/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.2027 - accuracy: 0.9156 - val_loss: 0.1843 - val_accuracy: 0.9200
# Epoch 27/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.2077 - accuracy: 0.9187 - val_loss: 0.1760 - val_accuracy: 0.9267
# Epoch 28/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.2068 - accuracy: 0.9219 - val_loss: 0.1728 - val_accuracy: 0.9200
# Epoch 29/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.2360 - accuracy: 0.9062 - val_loss: 0.1759 - val_accuracy: 0.9200
# Epoch 30/50
# 10/10 [==============================] - 32s 3s/step - loss: 0.2380 - accuracy: 0.8969 - val_loss: 0.1761 - val_accuracy: 0.9200
# Epoch 31/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.2098 - accuracy: 0.9125 - val_loss: 0.1661 - val_accuracy: 0.9267
# Epoch 32/50
# 10/10 [==============================] - 33s 3s/step - loss: 0.2125 - accuracy: 0.9219 - val_loss: 0.1653 - val_accuracy: 0.9267
# Epoch 33/50
# 10/10 [==============================] - 33s 3s/step - loss: 0.2057 - accuracy: 0.9281 - val_loss: 0.1677 - val_accuracy: 0.9267
# Epoch 34/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.1825 - accuracy: 0.9344 - val_loss: 0.1631 - val_accuracy: 0.9267
# Epoch 35/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.1960 - accuracy: 0.9281 - val_loss: 0.1631 - val_accuracy: 0.9200
# Epoch 36/50
# 10/10 [==============================] - 32s 3s/step - loss: 0.2296 - accuracy: 0.9094 - val_loss: 0.1647 - val_accuracy: 0.9267
# Epoch 37/50
# 10/10 [==============================] - 32s 3s/step - loss: 0.1663 - accuracy: 0.9500 - val_loss: 0.1603 - val_accuracy: 0.9267
# Epoch 38/50
# 10/10 [==============================] - 32s 3s/step - loss: 0.1717 - accuracy: 0.9406 - val_loss: 0.1587 - val_accuracy: 0.9267
# Epoch 39/50
# 10/10 [==============================] - 32s 3s/step - loss: 0.1534 - accuracy: 0.9625 - val_loss: 0.1585 - val_accuracy: 0.9333
# Epoch 40/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.2054 - accuracy: 0.9219 - val_loss: 0.1659 - val_accuracy: 0.9200
# Epoch 41/50
# 10/10 [==============================] - 32s 3s/step - loss: 0.1720 - accuracy: 0.9531 - val_loss: 0.1735 - val_accuracy: 0.9200
# Epoch 42/50
# 10/10 [==============================] - 32s 3s/step - loss: 0.1704 - accuracy: 0.9375 - val_loss: 0.1694 - val_accuracy: 0.9400
# Epoch 43/50
# 10/10 [==============================] - 32s 3s/step - loss: 0.1535 - accuracy: 0.9438 - val_loss: 0.1619 - val_accuracy: 0.9333
# Epoch 44/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.1806 - accuracy: 0.9375 - val_loss: 0.1546 - val_accuracy: 0.9333
# Epoch 45/50
# 10/10 [==============================] - 32s 3s/step - loss: 0.1968 - accuracy: 0.9375 - val_loss: 0.1503 - val_accuracy: 0.9400
# Epoch 46/50
# 10/10 [==============================] - 32s 3s/step - loss: 0.2207 - accuracy: 0.9187 - val_loss: 0.1486 - val_accuracy: 0.9467
# Epoch 47/50
# 10/10 [==============================] - 32s 3s/step - loss: 0.1746 - accuracy: 0.9312 - val_loss: 0.1492 - val_accuracy: 0.9400
# Epoch 48/50
# 10/10 [==============================] - 32s 3s/step - loss: 0.1729 - accuracy: 0.9438 - val_loss: 0.1514 - val_accuracy: 0.9400
# Epoch 49/50
# 10/10 [==============================] - 32s 3s/step - loss: 0.1960 - accuracy: 0.9375 - val_loss: 0.1447 - val_accuracy: 0.9467
# Epoch 50/50
# 10/10 [==============================] - 32s 3s/step - loss: 0.1845 - accuracy: 0.9344 - val_loss: 0.1413 - val_accuracy: 0.9467

# %%
model.save('cats-dogs-vgg16_my.hdf5')

# %%
len(train_files)
# Out:
# 25000

# %%
test_pred = model.predict(
    predict_generator(test_files), steps=len(test_files))
# Out:
# 12500/12500 [==============================] - 981s 78ms/step

# %%
fig = plt.figure(figsize=(16, 8))
for i, (path, score) in enumerate(zip(test_files[:10], test_pred[:10]), 1):
    subplot = fig.add_subplot(2, 5, i)
    subplot.set_title('%.2f %s' % (score, os.path.basename(path)))
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, IMG_SIZE)
    subplot.imshow(img)

# %%
import re

with open('submit_4.txt', 'w') as dst:
    dst.write('id,label\n')
    for path, score in zip(test_files, test_pred):
        dst.write('%s,%f\n' % (re.search('(\d+).jpg$', path).group(1), score))

# %% [markdown]
# Проблема с Кагглом никуда не делась. Какой телефон ему нужен не понимаю. Пробывал несколько. И где искать альтернативный номер непонятно.

# %% [markdown]
# ![image.png](attachment:image.png)
